# %% [markdown]
# # Artificial Intelligence Nanodegree
#
# ## Convolutional Neural Networks
#
# ---
#
# In this notebook, we train a CNN to classify images from the CIFAR-10 database.
#
# ### 1. Load CIFAR-10 Database

# %%
import keras
from keras.datasets import cifar10

# load the pre-shuffled train and test data
(x_train, y_train), (x_test, y_test) = cifar10.load_data()
# Out:
# Using TensorFlow backend.

# %% [markdown]
# ### 2. Visualize the First 24 Training Images

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

fig = plt.figure(figsize=(20,5))
for i in range(36):
    ax = fig.add_subplot(3, 12, i + 1, xticks=[], yticks=[])
    ax.imshow(np.squeeze(x_train[i]))

# %% [markdown]
# ### 3. Rescale the Images by Dividing Every Pixel in Every Image by 255

# %%
# rescale [0,255] --> [0,1]
x_train = x_train.astype('float32')/255
x_test = x_test.astype('float32')/255

# %% [markdown]
# ### 4.  Break Dataset into Training, Testing, and Validation Sets

# %%
from keras.utils import np_utils

# one-hot encode the labels
num_classes = len(np.unique(y_train))
y_train = keras.utils.to_categorical(y_train, num_classes)
y_test = keras.utils.to_categorical(y_test, num_classes)

# break training set into training and validation sets
(x_train, x_valid) = x_train[5000:], x_train[:5000]
(y_train, y_valid) = y_train[5000:], y_train[:5000]

# print shape of training set
print('x_train shape:', x_train.shape)

# print number of training, validation, and test images
print(x_train.shape[0], 'train samples')
print(x_test.shape[0], 'test samples')
print(x_valid.shape[0], 'validation samples')
# Out:
# x_train shape: (45000, 32, 32, 3)
# 45000 train samples
# 10000 test samples
# 5000 validation samples

# %% [markdown]
# ### 5. Define the Model Architecture

# %%
from keras.models import Sequential
from keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout

model = Sequential()
model.add(Conv2D(filters=16, kernel_size=2, padding='same', activation='relu', 
                        input_shape=(32, 32, 3)))
model.add(MaxPooling2D(pool_size=2))
model.add(Conv2D(filters=32, kernel_size=2, padding='same', activation='relu'))
model.add(MaxPooling2D(pool_size=2))
model.add(Conv2D(filters=64, kernel_size=2, padding='same', activation='relu'))
model.add(MaxPooling2D(pool_size=2))
model.add(Dropout(0.3))
model.add(Flatten())
model.add(Dense(500, activation='relu'))
model.add(Dropout(0.4))
model.add(Dense(10, activation='softmax'))

model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_1 (Conv2D)            (None, 32, 32, 16)        208
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 16, 16, 16)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 16, 16, 32)        2080
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 8, 8, 32)          0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 8, 8, 64)          8256
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 4, 4, 64)          0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 4, 4, 64)          0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 1024)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 500)               512500
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 500)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 10)                5010
# =================================================================
# Total params: 528,054
# Trainable params: 528,054
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ### 6. Compile the Model

# %%
# compile the model
model.compile(loss='categorical_crossentropy', optimizer='rmsprop', 
                  metrics=['accuracy'])

# %% [markdown]
# ### 7. Train the Model

# %%
from keras.callbacks import ModelCheckpoint   

# train the model
checkpointer = ModelCheckpoint(filepath='model.weights.best.hdf5', verbose=1, 
                               save_best_only=True)
hist = model.fit(x_train, y_train, batch_size=32, epochs=100,
          validation_data=(x_valid, y_valid), callbacks=[checkpointer], 
          verbose=2, shuffle=True)
# Out:
# Train on 45000 samples, validate on 5000 samples
# Epoch 1/100
# Epoch 00000: val_loss improved from inf to 1.32969, saving model to model.weights.best.hdf5
# 36s - loss: 1.6020 - acc: 0.4214 - val_loss: 1.3297 - val_acc: 0.5352
# Epoch 2/100
# Epoch 00001: val_loss improved from 1.32969 to 1.18902, saving model to model.weights.best.hdf5
# 11s - loss: 1.2901 - acc: 0.5405 - val_loss: 1.1890 - val_acc: 0.5718
# Epoch 3/100
# Epoch 00002: val_loss did not improve
# 11s - loss: 1.1713 - acc: 0.5863 - val_loss: 1.2657 - val_acc: 0.5578
# Epoch 4/100
# Epoch 00003: val_loss improved from 1.18902 to 1.02823, saving model to model.weights.best.hdf5
# 11s - loss: 1.0953 - acc: 0.6154 - val_loss: 1.0282 - val_acc: 0.6422
# Epoch 5/100
# Epoch 00004: val_loss did not improve
# 11s - loss: 1.0564 - acc: 0.6328 - val_loss: 1.1311 - val_acc: 0.6028
# Epoch 6/100
# Epoch 00005: val_loss improved from 1.02823 to 0.94225, saving model to model.weights.best.hdf5
# 11s - loss: 1.0316 - acc: 0.6434 - val_loss: 0.9423 - val_acc: 0.6734
# Epoch 7/100
# Epoch 00006: val_loss did not improve
# 11s - loss: 1.0221 - acc: 0.6518 - val_loss: 0.9902 - val_acc: 0.6862
# Epoch 8/100
# Epoch 00007: val_loss did not improve
# 11s - loss: 1.0119 - acc: 0.6545 - val_loss: 0.9747 - val_acc: 0.6888
# Epoch 9/100
# Epoch 00008: val_loss did not improve
# 11s - loss: 1.0066 - acc: 0.6587 - val_loss: 0.9917 - val_acc: 0.6664
# Epoch 10/100
# Epoch 00009: val_loss did not improve
# 11s - loss: 1.0061 - acc: 0.6615 - val_loss: 1.1742 - val_acc: 0.6036
# Epoch 11/100
# Epoch 00010: val_loss did not improve
# 11s - loss: 1.0073 - acc: 0.6597 - val_loss: 1.0324 - val_acc: 0.6612
# Epoch 12/100
# Epoch 00011: val_loss did not improve
# 11s - loss: 1.0051 - acc: 0.6615 - val_loss: 0.9749 - val_acc: 0.6816
# Epoch 13/100
# Epoch 00012: val_loss did not improve
# 11s - loss: 1.0161 - acc: 0.6576 - val_loss: 0.9601 - val_acc: 0.6908
# Epoch 14/100
# Epoch 00013: val_loss did not improve
# 11s - loss: 1.0298 - acc: 0.6531 - val_loss: 1.2803 - val_acc: 0.6332
# Epoch 15/100
# Epoch 00014: val_loss did not improve
# 11s - loss: 1.0417 - acc: 0.6542 - val_loss: 0.9722 - val_acc: 0.6916
# Epoch 16/100
# Epoch 00015: val_loss did not improve
# 11s - loss: 1.0558 - acc: 0.6521 - val_loss: 1.1147 - val_acc: 0.6376
# Epoch 17/100
# Epoch 00016: val_loss did not improve
# 11s - loss: 1.0652 - acc: 0.6476 - val_loss: 0.9763 - val_acc: 0.6760
# Epoch 18/100
# Epoch 00017: val_loss did not improve
# 11s - loss: 1.0816 - acc: 0.6453 - val_loss: 1.0196 - val_acc: 0.6672
# Epoch 19/100
# Epoch 00018: val_loss did not improve
# 11s - loss: 1.1040 - acc: 0.6355 - val_loss: 1.2497 - val_acc: 0.5960
# Epoch 20/100
# Epoch 00019: val_loss did not improve
# 11s - loss: 1.1259 - acc: 0.6291 - val_loss: 1.4440 - val_acc: 0.6030
# Epoch 21/100
# Epoch 00020: val_loss did not improve
# 11s - loss: 1.1506 - acc: 0.6223 - val_loss: 1.2877 - val_acc: 0.5998
# Epoch 22/100
# Epoch 00021: val_loss did not improve
# 11s - loss: 1.1697 - acc: 0.6193 - val_loss: 1.0832 - val_acc: 0.6416
# Epoch 23/100
# Epoch 00022: val_loss did not improve
# 11s - loss: 1.1892 - acc: 0.6084 - val_loss: 1.0645 - val_acc: 0.6434
# Epoch 24/100
# Epoch 00023: val_loss did not improve
# 11s - loss: 1.2025 - acc: 0.6067 - val_loss: 1.0937 - val_acc: 0.6232
# Epoch 25/100
# Epoch 00024: val_loss did not improve
# 11s - loss: 1.2237 - acc: 0.5996 - val_loss: 1.2976 - val_acc: 0.6068
# Epoch 26/100
# Epoch 00025: val_loss did not improve
# 11s - loss: 1.2377 - acc: 0.5955 - val_loss: 1.3064 - val_acc: 0.5612
# Epoch 27/100
# Epoch 00026: val_loss did not improve
# 11s - loss: 1.2686 - acc: 0.5868 - val_loss: 1.3467 - val_acc: 0.6070
# Epoch 28/100
# Epoch 00027: val_loss did not improve
# 11s - loss: 1.2874 - acc: 0.5817 - val_loss: 1.6211 - val_acc: 0.6078
# Epoch 29/100
# Epoch 00028: val_loss did not improve
# 11s - loss: 1.3015 - acc: 0.5745 - val_loss: 1.2179 - val_acc: 0.5930
# Epoch 30/100
# Epoch 00029: val_loss did not improve
# 11s - loss: 1.3054 - acc: 0.5720 - val_loss: 1.2523 - val_acc: 0.6200
# Epoch 31/100
# Epoch 00030: val_loss did not improve
# 11s - loss: 1.3405 - acc: 0.5596 - val_loss: 1.2062 - val_acc: 0.6230
# Epoch 32/100
# Epoch 00031: val_loss did not improve
# 11s - loss: 1.3454 - acc: 0.5572 - val_loss: 1.5173 - val_acc: 0.5422
# Epoch 33/100
# Epoch 00032: val_loss did not improve
# 11s - loss: 1.3569 - acc: 0.5502 - val_loss: 1.3805 - val_acc: 0.5272
# Epoch 34/100
# Epoch 00033: val_loss did not improve
# 11s - loss: 1.3691 - acc: 0.5502 - val_loss: 1.2966 - val_acc: 0.5696
# Epoch 35/100
# Epoch 00034: val_loss did not improve
# 11s - loss: 1.3809 - acc: 0.5429 - val_loss: 2.4788 - val_acc: 0.5350
# Epoch 36/100
# Epoch 00035: val_loss did not improve
# 11s - loss: 1.4005 - acc: 0.5412 - val_loss: 1.1887 - val_acc: 0.6014
# Epoch 37/100
# Epoch 00036: val_loss did not improve
# 11s - loss: 1.4100 - acc: 0.5342 - val_loss: 1.2879 - val_acc: 0.5532
# Epoch 38/100
# Epoch 00037: val_loss did not improve
# 11s - loss: 1.4217 - acc: 0.5286 - val_loss: 1.9090 - val_acc: 0.4690
# Epoch 39/100
# Epoch 00038: val_loss did not improve
# 11s - loss: 1.4231 - acc: 0.5239 - val_loss: 1.3731 - val_acc: 0.5816
# Epoch 40/100
# Epoch 00039: val_loss did not improve
# 11s - loss: 1.4450 - acc: 0.5154 - val_loss: 1.3365 - val_acc: 0.5280
# Epoch 41/100
# Epoch 00040: val_loss did not improve
# 11s - loss: 1.4466 - acc: 0.5148 - val_loss: 1.2101 - val_acc: 0.5982
# Epoch 42/100
# Epoch 00041: val_loss did not improve
# 11s - loss: 1.4496 - acc: 0.5172 - val_loss: 1.3580 - val_acc: 0.5382
# Epoch 43/100
# Epoch 00042: val_loss did not improve
# 11s - loss: 1.4619 - acc: 0.5136 - val_loss: 1.8704 - val_acc: 0.5058
# Epoch 44/100
# Epoch 00043: val_loss did not improve
# 11s - loss: 1.4718 - acc: 0.5048 - val_loss: 1.4769 - val_acc: 0.5060
# Epoch 45/100
# Epoch 00044: val_loss did not improve
# 11s - loss: 1.4813 - acc: 0.4996 - val_loss: 1.2868 - val_acc: 0.5730
# Epoch 46/100
# Epoch 00045: val_loss did not improve
# 11s - loss: 1.4982 - acc: 0.4971 - val_loss: 1.5476 - val_acc: 0.5298
# Epoch 47/100
# Epoch 00046: val_loss did not improve
# 11s - loss: 1.5139 - acc: 0.4927 - val_loss: 1.5684 - val_acc: 0.4468
# Epoch 48/100
# Epoch 00047: val_loss did not improve
# 11s - loss: 1.5101 - acc: 0.4939 - val_loss: 1.4484 - val_acc: 0.5102
# Epoch 49/100
# Epoch 00048: val_loss did not improve
# 11s - loss: 1.5343 - acc: 0.4869 - val_loss: 1.2666 - val_acc: 0.5684
# Epoch 50/100
# Epoch 00049: val_loss did not improve
# 11s - loss: 1.5360 - acc: 0.4826 - val_loss: 1.2668 - val_acc: 0.5712
# Epoch 51/100
# Epoch 00050: val_loss did not improve
# 11s - loss: 1.5585 - acc: 0.4736 - val_loss: 1.4617 - val_acc: 0.5090
# Epoch 52/100
# Epoch 00051: val_loss did not improve
# 11s - loss: 1.5768 - acc: 0.4687 - val_loss: 1.4792 - val_acc: 0.4684
# Epoch 53/100
# Epoch 00052: val_loss did not improve
# 11s - loss: 1.6043 - acc: 0.4624 - val_loss: 2.5102 - val_acc: 0.4740
# Epoch 54/100
# Epoch 00053: val_loss did not improve
# 11s - loss: 1.6122 - acc: 0.4504 - val_loss: 1.8634 - val_acc: 0.3674
# Epoch 55/100
# Epoch 00054: val_loss did not improve
# 11s - loss: 1.6306 - acc: 0.4461 - val_loss: 1.3320 - val_acc: 0.5386
# Epoch 56/100
# Epoch 00055: val_loss did not improve
# 11s - loss: 1.6530 - acc: 0.4377 - val_loss: 1.3797 - val_acc: 0.5030
# Epoch 57/100
# Epoch 00056: val_loss did not improve
# 11s - loss: 1.6475 - acc: 0.4375 - val_loss: 3.7860 - val_acc: 0.3382
# Epoch 58/100
# Epoch 00057: val_loss did not improve
# 11s - loss: 1.6669 - acc: 0.4316 - val_loss: 1.6241 - val_acc: 0.4386
# Epoch 59/100
# Epoch 00058: val_loss did not improve
# 11s - loss: 1.6735 - acc: 0.4282 - val_loss: 1.5080 - val_acc: 0.4734
# Epoch 60/100
# Epoch 00059: val_loss did not improve
# 11s - loss: 1.6878 - acc: 0.4211 - val_loss: 1.5607 - val_acc: 0.4328
# Epoch 61/100
# Epoch 00060: val_loss did not improve
# 11s - loss: 1.7021 - acc: 0.4169 - val_loss: 1.3765 - val_acc: 0.5242
# Epoch 62/100
# Epoch 00061: val_loss did not improve
# 11s - loss: 1.6770 - acc: 0.4192 - val_loss: 1.4594 - val_acc: 0.4738
# Epoch 63/100
# Epoch 00062: val_loss did not improve
# 11s - loss: 1.7091 - acc: 0.4112 - val_loss: 1.5355 - val_acc: 0.4560
# Epoch 64/100
# Epoch 00063: val_loss did not improve
# 11s - loss: 1.6896 - acc: 0.4133 - val_loss: 1.4364 - val_acc: 0.4998
# Epoch 65/100
# Epoch 00064: val_loss did not improve
# 11s - loss: 1.7004 - acc: 0.4123 - val_loss: 1.4833 - val_acc: 0.4778
# Epoch 66/100
# Epoch 00065: val_loss did not improve
# 11s - loss: 1.7037 - acc: 0.4154 - val_loss: 1.7408 - val_acc: 0.4246
# Epoch 67/100
# Epoch 00066: val_loss did not improve
# 11s - loss: 1.7201 - acc: 0.4104 - val_loss: 2.0673 - val_acc: 0.3982
# Epoch 68/100
# Epoch 00067: val_loss did not improve
# 11s - loss: 1.7013 - acc: 0.4090 - val_loss: 1.5548 - val_acc: 0.4610
# Epoch 69/100
# Epoch 00068: val_loss did not improve
# 11s - loss: 1.7126 - acc: 0.4059 - val_loss: 1.5521 - val_acc: 0.4380
# Epoch 70/100
# Epoch 00069: val_loss did not improve
# 11s - loss: 1.7291 - acc: 0.3980 - val_loss: 1.8250 - val_acc: 0.4224
# Epoch 71/100
# Epoch 00070: val_loss did not improve
# 11s - loss: 1.7220 - acc: 0.4028 - val_loss: 1.5414 - val_acc: 0.4610
# Epoch 72/100
# Epoch 00071: val_loss did not improve
# 11s - loss: 1.7253 - acc: 0.3985 - val_loss: 1.5509 - val_acc: 0.4598
# Epoch 73/100
# Epoch 00072: val_loss did not improve
# 11s - loss: 1.7325 - acc: 0.3928 - val_loss: 1.5772 - val_acc: 0.4326
# Epoch 74/100
# Epoch 00073: val_loss did not improve
# 11s - loss: 1.7465 - acc: 0.3904 - val_loss: 1.6383 - val_acc: 0.4392
# Epoch 75/100
# Epoch 00074: val_loss did not improve
# 11s - loss: 1.7546 - acc: 0.3934 - val_loss: 1.6953 - val_acc: 0.3830
# Epoch 76/100
# Epoch 00075: val_loss did not improve
# 11s - loss: 1.7413 - acc: 0.3903 - val_loss: 1.6400 - val_acc: 0.4648
# Epoch 77/100
# Epoch 00076: val_loss did not improve
# 11s - loss: 1.7481 - acc: 0.3902 - val_loss: 1.6788 - val_acc: 0.3934
# Epoch 78/100
# Epoch 00077: val_loss did not improve
# 11s - loss: 1.7498 - acc: 0.3889 - val_loss: 1.4975 - val_acc: 0.4638
# Epoch 79/100
# Epoch 00078: val_loss did not improve
# 11s - loss: 1.7610 - acc: 0.3820 - val_loss: 1.7119 - val_acc: 0.3372
# Epoch 80/100
# Epoch 00079: val_loss did not improve
# 11s - loss: 1.7655 - acc: 0.3764 - val_loss: 1.6425 - val_acc: 0.4148
# Epoch 81/100
# Epoch 00080: val_loss did not improve
# 11s - loss: 1.7568 - acc: 0.3828 - val_loss: 1.6693 - val_acc: 0.4498
# Epoch 82/100
# Epoch 00081: val_loss did not improve
# 11s - loss: 1.7641 - acc: 0.3791 - val_loss: 1.6170 - val_acc: 0.4032
# Epoch 83/100
# Epoch 00082: val_loss did not improve
# 11s - loss: 1.7594 - acc: 0.3836 - val_loss: 1.6887 - val_acc: 0.3834
# Epoch 84/100
# Epoch 00083: val_loss did not improve
# 11s - loss: 1.7523 - acc: 0.3819 - val_loss: 1.5294 - val_acc: 0.4636
# Epoch 85/100
# Epoch 00084: val_loss did not improve
# 11s - loss: 1.7677 - acc: 0.3749 - val_loss: 5.0542 - val_acc: 0.2950
# Epoch 86/100
# Epoch 00085: val_loss did not improve
# 11s - loss: 1.7810 - acc: 0.3753 - val_loss: 1.5775 - val_acc: 0.4392
# Epoch 87/100
# Epoch 00086: val_loss did not improve
# 11s - loss: 1.7776 - acc: 0.3713 - val_loss: 1.5298 - val_acc: 0.4532
# Epoch 88/100
# Epoch 00087: val_loss did not improve
# 11s - loss: 1.7862 - acc: 0.3676 - val_loss: 1.5502 - val_acc: 0.4306
# Epoch 89/100
# Epoch 00088: val_loss did not improve
# 11s - loss: 1.7839 - acc: 0.3674 - val_loss: 1.6229 - val_acc: 0.4070
# Epoch 90/100
# Epoch 00089: val_loss did not improve
# 11s - loss: 1.8067 - acc: 0.3625 - val_loss: 1.7292 - val_acc: 0.3768
# Epoch 91/100
# Epoch 00090: val_loss did not improve
# 11s - loss: 1.7886 - acc: 0.3648 - val_loss: 1.5792 - val_acc: 0.4066
# Epoch 92/100
# Epoch 00091: val_loss did not improve
# 11s - loss: 1.8075 - acc: 0.3568 - val_loss: 2.5886 - val_acc: 0.3442
# Epoch 93/100
# Epoch 00092: val_loss did not improve
# 11s - loss: 1.8057 - acc: 0.3519 - val_loss: 1.8197 - val_acc: 0.3882
# Epoch 94/100
# Epoch 00093: val_loss did not improve
# 11s - loss: 1.8128 - acc: 0.3560 - val_loss: 1.8475 - val_acc: 0.3442
# Epoch 95/100
# Epoch 00094: val_loss did not improve
# 11s - loss: 1.8149 - acc: 0.3524 - val_loss: 2.0039 - val_acc: 0.3420
# Epoch 96/100
# Epoch 00095: val_loss did not improve
# 11s - loss: 1.8070 - acc: 0.3504 - val_loss: 1.9320 - val_acc: 0.4140
# Epoch 97/100
# Epoch 00096: val_loss did not improve
# 11s - loss: 1.8330 - acc: 0.3463 - val_loss: 1.9032 - val_acc: 0.3948
# Epoch 98/100
# Epoch 00097: val_loss did not improve
# 11s - loss: 1.8109 - acc: 0.3491 - val_loss: 1.7374 - val_acc: 0.3930
# Epoch 99/100
# Epoch 00098: val_loss did not improve
# 11s - loss: 1.8316 - acc: 0.3391 - val_loss: 2.1694 - val_acc: 0.3370
# Epoch 100/100
# Epoch 00099: val_loss did not improve
# 11s - loss: 1.8335 - acc: 0.3396 - val_loss: 1.9493 - val_acc: 0.2888

# %% [markdown]
# ### 8. Load the Model with the Best Validation Accuracy

# %%
# load the weights that yielded the best validation accuracy
model.load_weights('model.weights.best.hdf5')

# %% [markdown]
# ### 9. Calculate Classification Accuracy on Test Set

# %%
# evaluate and print test accuracy
score = model.evaluate(x_test, y_test, verbose=0)
print('\n', 'Test accuracy:', score[1])
# Out:
#  Test accuracy: 0.667

# %% [markdown]
# ### 10. Visualize Some Predictions
#
# This may give you some insight into why the network is misclassifying certain objects.

# %%
# get predictions on the test set
y_hat = model.predict(x_test)

# define text labels (source: https://www.cs.toronto.edu/~kriz/cifar.html)
cifar10_labels = ['airplane', 'automobile', 'bird', 'cat', 'deer', 'dog', 'frog', 'horse', 'ship', 'truck']

# %%
# plot a random sample of test images, their predicted labels, and ground truth
fig = plt.figure(figsize=(20, 8))
for i, idx in enumerate(np.random.choice(x_test.shape[0], size=32, replace=False)):
    ax = fig.add_subplot(4, 8, i + 1, xticks=[], yticks=[])
    ax.imshow(np.squeeze(x_test[idx]))
    pred_idx = np.argmax(y_hat[idx])
    true_idx = np.argmax(y_test[idx])
    ax.set_title("{} ({})".format(cifar10_labels[pred_idx], cifar10_labels[true_idx]),
                 color=("green" if pred_idx == true_idx else "red"))
